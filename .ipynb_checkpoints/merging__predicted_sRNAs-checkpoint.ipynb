# %%
import sys
from Bio import SeqIO
import pandas as pd

# %%
# "~/phd/RNASeq/srna_seqs/version_1/predicted/original_stats_2.txt"
alignment_file_counts = pd.read_csv("/Users/thomasnicholson/phd/RNASeq/srna_seqs/version_1/predicted/original_stats_2.txt", 
                                    header=None, delim_whitespace=True, names=list('abcdef'))
alignment_file_counts = alignment_file_counts.loc[alignment_file_counts['a'] == 'Number_of_sequences:']
alignment_file_counts = alignment_file_counts[['b', 'c']]

alignment_file_counts.columns = ['count', 'id']

alignment_file_counts['id'] = alignment_file_counts['id'].str.replace('.stk', '')
alignment_file_counts.set_index('id', inplace=True)

target_counts = alignment_file_counts.to_dict()

target_counts
# Out:
# {'count': {'GCA_000006765.1_331': '48',
#   'GCA_000006765.1_548': '16',
#   'GCA_000006765.1_712': '6',
#   'GCA_000006765.1_715': '10',
#   'GCA_000006765.1_814': '7',
#   'GCA_000006765.1_9': '38',
#   'GCA_000006945.2_4190': '17',
#   'GCA_000006945.2_4954': '3',
#   'GCA_000006945.2_4959': '6',
#   'GCA_000006945.2_4960': '4',
#   'GCA_000006945.2_4963': '3',
#   'GCA_000007405.1_142': '17',
#   'GCA_000007405.1_150': '20',
#   'GCA_000007405.1_212': '17',
#   'GCA_000007405.1_214': '20',
#   'GCA_000007405.1_27': '20',
#   'GCA_000007405.1_277': '8',
#   'GCA_000007405.1_296': '23',
#   'GCA_000007405.1_317': '7',
#   'GCA_000007405.1_329': '20',
#   'GCA_000007405.1_337': '9',
#   'GCA_000007405.1_368': '4',
#   'GCA_000007405.1_426': '2',
#   'GCA_000007405.1_459': '9',
#   'GCA_000007405.1_464': '23',
#   'GCA_000007405.1_567': '23',
#   'GCA_000007405.1_57': '20',
#   'GCA_000007405.1_6': '9',
#   'GCA_000007405.1_60': '9',
#   'GCA_000007405.1_603': '27',
#   'GCA_000007405.1_629': '9',
#   'GCA_000007405.1_639': '9',
#   'GCA_000007405.1_642': '15',
#   'GCA_000007405.1_652': '9',
#   'GCA_000007405.1_664': '7',
#   'GCA_000007405.1_675': '3',
#   'GCA_000007405.1_693': '8',
#   'GCA_000007405.1_88': '23',
#   'GCA_000007565.2_111': '2',
#   'GCA_000007565.2_113': '2',
#   'GCA_000007565.2_116': '3',
#   'GCA_000007565.2_162': '3',
#   'GCA_000007565.2_215': '3',
#   'GCA_000007565.2_238': '4',
#   'GCA_000007565.2_261': '5',
#   'GCA_000007565.2_270': '15',
#   'GCA_000007565.2_291': '3',
#   'GCA_000007565.2_294': '102',
#   'GCA_000007565.2_300': '3',
#   'GCA_000007565.2_316': '6',
#   'GCA_000007565.2_337': '3',
#   'GCA_000007565.2_350': '7',
#   'GCA_000007565.2_363': '5',
#   'GCA_000007565.2_372': '2',
#   'GCA_000007565.2_38': '6',
#   'GCA_000007565.2_387': '3',
#   'GCA_000007565.2_40': '3',
#   'GCA_000007565.2_98': '2',
#   'GCA_000015425.1_102': '14',
#   'GCA_000015425.1_250': '17',
#   'GCA_000015425.1_300': '70',
#   'GCA_000015425.1_39': '7',
#   'GCA_000015425.1_82': '3',
#   'GCA_002220715.1_288': '3',
#   'GCA_002220715.1_313': '3',
#   'GCA_002220715.1_40': '3',
#   'GCA_002220715.1_78': '3',
#   'GCA_002303275.1_122': '20',
#   'GCA_002355295.1_21': '2',
#   'GCA_002355295.1_3': '365',
#   'GCA_002355295.1_31': '107',
#   'GCA_002355295.1_429': '89',
#   'GCA_002355295.1_434': '4',
#   'GCA_002355295.1_553': '110',
#   'GCA_002355295.1_556': '2',
#   'GCA_002504125.1_124': '6',
#   'GCA_002504125.1_182': '6',
#   'GCA_002504125.1_187': '6',
#   'GCA_002504125.1_192': '14',
#   'GCA_002504125.1_290': '20',
#   'GCA_002504125.1_302': '20',
#   'GCA_002504125.1_377': '27',
#   'GCA_002504125.1_413': '5',
#   'GCA_002504125.1_415': '18',
#   'GCA_002504125.1_421': '21',
#   'GCA_002504125.1_428': '10',
#   'GCA_002813995.1_127': '6',
#   'GCA_002813995.1_15': '161',
#   'GCA_002813995.1_150': '8',
#   'GCA_002813995.1_160': '177',
#   'GCA_002813995.1_203': '21',
#   'GCA_002813995.1_231': '6',
#   'GCA_002813995.1_263': '6',
#   'GCA_002813995.1_385': '4',
#   'GCA_002813995.1_396': '21',
#   'GCA_002813995.1_410': '9',
#   'GCA_002813995.1_415': '4',
#   'GCA_002813995.1_420': '108',
#   'GCA_002813995.1_421': '22',
#   'GCA_002813995.1_50': '6',
#   'GCA_002813995.1_62': '5',
#   'GCA_002813995.1_72': '18',
#   'GCA_002843685.1_123': '9',
#   'GCA_002843685.1_294': '103',
#   'GCA_002848605.1_107': '20',
#   'GCA_002848605.1_113': '20',
#   'GCA_002848605.1_124': '2',
#   'GCA_002848605.1_126': '2',
#   'GCA_002848605.1_130': '2',
#   'GCA_002848605.1_166': '2',
#   'GCA_002848605.1_180': '2',
#   'GCA_002848605.1_204': '2',
#   'GCA_002848605.1_208': '3',
#   'GCA_002848605.1_213': '2',
#   'GCA_002848605.1_214': '2',
#   'GCA_002848605.1_280': '2',
#   'GCA_002848605.1_311': '2',
#   'GCA_002848605.1_318': '3',
#   'GCA_002848605.1_323': '21',
#   'GCA_002848605.1_327': '4',
#   'GCA_002848605.1_84': '3',
#   'GCA_002848605.1_97': '2',
#   'GCA_002849875.1_13': '18',
#   'GCA_002850215.1_101': '3',
#   'GCA_002850215.1_103': '3',
#   'GCA_002850215.1_108': '3',
#   'GCA_002850215.1_109': '3',
#   'GCA_002850215.1_116': '3',
#   'GCA_002850215.1_12': '3',
#   'GCA_002850215.1_129': '3',
#   'GCA_002850215.1_14': '3',
#   'GCA_002850215.1_152': '3',
#   'GCA_002850215.1_154': '3',
#   'GCA_002850215.1_158': '3',
#   'GCA_002850215.1_16': '3',
#   'GCA_002850215.1_161': '3',
#   'GCA_002850215.1_162': '3',
#   'GCA_002850215.1_168': '3',
#   'GCA_002850215.1_180': '3',
#   'GCA_002850215.1_181': '4',
#   'GCA_002850215.1_183': '3',
#   'GCA_002850215.1_191': '3',
#   'GCA_002850215.1_196': '3',
#   'GCA_002850215.1_217': '3',
#   'GCA_002850215.1_224': '3',
#   'GCA_900243355.1_544': '46',
#   'GCA_900243355.1_554': '25',
#   'GCA_900243355.1_592': '33',
#   'GCA_900243355.1_604': '77',
#   'GCA_900243355.1_682': '14',
#   'GCA_900243355.1_755': '4',
#   'GCA_900243355.1_774': '4'}}

# %%
alignDat = pd.read_csv("/Users/thomasnicholson/phd/RNASeq/srna_seqs/version_1/predicted/predicted_genomic_sequence_matches.txt", header=None, delim_whitespace=True)

alignDat = alignDat.iloc[:,[1,3]]
alignDat.columns = ["details", "query_id"]
alignDat[["target_contig", "coord"]] = alignDat.details.str.split("/", expand = True)
alignDat[["target_start", "target_end"]] = alignDat.coord.str.split("-", expand = True)
alignDat = alignDat[["query_id", "target_contig", "target_start", "target_end"]]
alignDat["target_start"] = alignDat["target_start"].astype(str).astype(int)
alignDat['target_start'].dtypes
alignDat["target_end"] = alignDat["target_end"].astype(str).astype(int)
alignDat['target_end'].dtypes
alignDat = alignDat.sort_values(by=['target_start'])
display(alignDat)
# Out:
#                     query_id  target_contig  target_start  target_end
# 102257   GCA_000283715.1_608    NC_016824.1             1         502
# 97980     GCA_000281215.1_63    NC_004578.1             1         169
# 143061    GCA_002208745.1_77    NC_004578.1             1         196
# 18031   GCA_000017745.1_1104  NZ_CP014273.1             1          88
# 49730      GCA_000017765.1_1    NC_004741.1             2         139
# ...                      ...            ...           ...         ...
# 237016   GCA_900243355.1_880    NC_004129.6       7072550     7072638
# 237049   GCA_900243355.1_881    NC_004129.6       7073958     7074088
# 10609      GCA_000007565.2_2    NC_004129.6       7074572     7074786
# 97979     GCA_000281215.1_63    NC_004129.6       7074629     7074825
# 143060    GCA_002208745.1_77    NC_004129.6       7074636     7074859
#
# [237090 rows x 4 columns]

# %%
target_contigs = alignDat.target_contig.unique()
display(target_contigs)
# Out:
# array(['NC_016824.1', 'NC_004578.1', 'NZ_CP014273.1', 'NC_004741.1',
#        'NC_009800.1', 'NC_009801.1', 'NC_012967.1', 'NZ_CP025268.1',
#        'NC_016822.1', 'NC_022912.1', 'NZ_CP014272.1', 'NZ_CP022097.1',
#        'NZ_CP025515.1', 'NZ_CP016634.1', 'NC_017720.1', 'NC_016823.1',
#        'NC_008463.1', 'NC_002516.2', 'NZ_CP018026.1', 'NC_019393.1',
#        'NC_016834.1', 'NC_015554.1', 'NC_009786.1', 'NZ_CP003425.1',
#        'NC_009791.1', 'NZ_CP025517.1', 'NZ_CP015641.1', 'NC_002947.4',
#        'NC_009788.1', 'NZ_CP003424.1', 'NZ_LT855377.1', 'NC_003277.2',
#        'NC_009790.1', 'NC_017718.1', 'NC_016833.1', 'NZ_CP025516.1',
#        'NC_009787.1', 'NZ_CP015527.1', 'NZ_CP011661.1', 'NZ_LT969519.1',
#        'NZ_CP011658.1', 'NC_022899.1', 'NZ_LT905143.1', 'NZ_CP011662.1',
#        'NC_021659.1', 'NC_017541.1', 'NZ_LT594096.1', 'NZ_CP019088.1',
#        'NZ_CP011961.1', 'NC_006834.1', 'NC_009084.1', 'NZ_CP020358.1',
#        'NC_017719.1', 'NC_009083.1', 'NC_017540.1', 'NC_018220.1',
#        'NZ_CP016446.1', 'NZ_CP017473.1', 'NZ_CP023465.1', 'NZ_CP011659.1',
#        'NZ_CP018920.1', 'NC_009789.1', 'NZ_CP018921.1', 'NZ_CP018919.1',
#        'NZ_LT906474.1', 'NZ_CP020359.1', 'NZ_CP022660.1', 'NC_003197.2',
#        'NC_016810.1', 'NZ_CP022658.1', 'NZ_LT855376.1', 'NZ_LT969520.1',
#        'NC_005966.1', 'NZ_LT594095.1', 'NC_009085.1', 'NZ_CP015526.1',
#        'NC_014259.1', 'NC_004129.6', 'NC_004633.1', 'NZ_CP018321.1',
#        'NZ_CP017475.1', 'NZ_CP022659.1', 'NZ_CP018922.1', 'NC_004632.1',
#        'NZ_LT969521.1', 'NC_019394.1', 'NZ_CP020659.1', 'NZ_CP018322.1'],
#       dtype=object)

# %%
query_ids = alignDat.query_id.unique()
display(query_ids)
# Out:
# array(['GCA_000283715.1_608', 'GCA_000281215.1_63', 'GCA_002208745.1_77',
#        ..., 'GCA_002072655.1_311', 'GCA_002072655.1_312',
#        'GCA_002072655.1_314'], dtype=object)

# %%
contig = target_contigs[1]
# print(contig)
subsetDat = alignDat.loc[alignDat['target_contig'] == contig]
display(subsetDat)
# Out:
#                    query_id target_contig  target_start  target_end
# 97980    GCA_000281215.1_63   NC_004578.1             1         169
# 143061   GCA_002208745.1_77   NC_004578.1             1         196
# 143077   GCA_002208745.1_78   NC_004578.1            17         192
# 8731      GCA_000007565.2_1   NC_004578.1            18         195
# 94392   GCA_000220485.1_557   NC_004578.1         23240       23737
# ...                     ...           ...           ...         ...
# 236913  GCA_900243355.1_877   NC_004578.1       6393548     6393697
# 236959  GCA_900243355.1_878   NC_004578.1       6394355     6394504
# 236971  GCA_900243355.1_879   NC_004578.1       6394567     6394704
# 237017  GCA_900243355.1_880   NC_004578.1       6395014     6395104
# 237050  GCA_900243355.1_881   NC_004578.1       6396412     6396538
#
# [3038 rows x 4 columns]

# %%
subsetDat['target_start'].dtypes
# Out:
# dtype('int64')

# %%
d = {}
def get_overlap_vals(subsetDat, overlaps):
    dat_len = len(subsetDat.index)
#     print(dat_len)
    overlapping_ids = []
    lengths = []
    start_val = 0
    end_val = 0
    for i in range(0,dat_len):
        query_val = subsetDat.iloc[i]['query_id']    
        new_start_val = min([subsetDat.iloc[i]['target_start'], subsetDat.iloc[i]['target_end']])
        new_end_val = max([subsetDat.iloc[i]['target_start'], subsetDat.iloc[i]['target_end']])
    #     print(query_val)
    #     print(new_start_val)
    #     print(new_end_val)    
        if end_val > new_start_val:
            overlapping_ids.append(query_val)
            len_1 = end_val - start_val
            len_2 = new_end_val - new_start_val
            shortest_seq = min([len_1, len_2])
            overlap_start = max([start_val, new_start_val])
            overlap_end = min([end_val, new_end_val])
            overlap = (overlap_end - overlap_start)/shortest_seq
            overlaps.append(overlap)
    #         print(overlap)
        else:
            end_val = new_end_val
            start_val = new_start_val
            overlapping_ids = [query_val]
    return(overlaps)
    #     print(overlapping_ids)

# %%
overlapping_ids = []
lengths = []
start_val = 0
end_val = 0
overlaps = []
for contig in target_contigs:
    subsetDat =  alignDat.loc[alignDat['target_contig'] == contig]
    overlaps = get_overlap_vals(subsetDat, overlaps)

# %%
import seaborn as sns

sns.displot(overlaps, kind="kde")

# %%
# display(target_contigs)

# %%
subsetDat =  alignDat.loc[alignDat['target_contig'] == "NC_004578.1"]
shortest_seq = max(subsetDat['target_end'])
display(shortest_seq)
# Out:
# 6396538

# %%
def get_overlap_list(subsetDat):
    
    overlapping_ids = []
    overlap_list = []
    lengths = []
    start_val = 0
    end_val = 0
    shortest_seq = max(subsetDat['target_end'])
    dat_len = len(subsetDat.index)
#     print(dat_len)
    for i in range(0,dat_len):
        query_val = subsetDat.iloc[i]['query_id']    
        new_start_val = min([subsetDat.iloc[i]['target_start'], subsetDat.iloc[i]['target_end']])
        new_end_val = max([subsetDat.iloc[i]['target_start'], subsetDat.iloc[i]['target_end']])
    #     print(query_val)
    #     print(new_start_val)
    #     print(new_end_val)    
        if end_val > new_start_val:
            len_2 = new_end_val - new_start_val
            shortest_seq = min([shortest_seq, len_2])
            overlap_start = max([start_val, new_start_val])
            overlap_end = min([end_val, new_end_val])
            overlap = (overlap_end - overlap_start)/shortest_seq
            
            if overlap >= 0.5 and overlap_end - overlap_start >= 50:
                overlapping_ids.append(query_val)
                end_val = max([end_val, new_end_val])
            else:
                overlap_list.append(overlapping_ids)
                shortest_seq = max(subsetDat['target_end'])
                end_val = new_end_val
                start_val = new_start_val
                overlapping_ids = [query_val]
        else:
            overlap_list.append(overlapping_ids)
            end_val = new_end_val
            start_val = new_start_val
            overlapping_ids = [query_val]
    return(overlap_list)
    #     print(overlapping_ids)

# %%
subsetDat =  alignDat.loc[alignDat['target_contig'] == "NC_004578.1"]
overlap_list = get_overlap_list(subsetDat = subsetDat)

# %%
d = {}
def get_overlap_count(overlap_list, d):
    for l in overlap_list:
        list_len = len(l)
        if list_len == 0:
            continue
        for i in range(0,list_len - 1):
            for j in range(i+1, list_len):
                ids =[l[i], l[j]]
                ids.sort()
                current_id = "_".join(ids)
                if current_id in d:
                    d[current_id] += 1
                else:
                    d[current_id] = 1
    return(d)

# %%
d = {}
for contig in target_contigs:
    subsetDat =  alignDat.loc[alignDat['target_contig'] == contig]
    overlap_list = get_overlap_list(subsetDat = subsetDat)
    d = get_overlap_count(overlap_list = overlap_list, d = d)

# %%
target_counts = {}
query  = query_ids[0]
for query in query_ids:
#     print(query)
    queryDat = alignDat.loc[alignDat['query_id'] == query]
    query_len = len(queryDat.index)
    target_counts[query] = query_len

# %%
query_matches = {}
query_counts = {}
# query_current_id = {}
overlap_percentages = []
for i in range(0, len(query_ids) -1):
    for j in range(i + 1, len(query_ids)):
        ids =[query_ids[i], query_ids[j]]
        ids.sort()
        current_id = "_".join(ids)
        count = min([target_counts[query_ids[i]], target_counts[query_ids[j]]])
        if current_id in d:
            if d[current_id]/count < 1:
                overlap_percentages.append(d[current_id]/count)
            else:
                overlap_percentages.append(1)
            if d[current_id]/count > 0.35:
                query_matches[current_id] = d[current_id]/count
                query_counts[current_id] = [d[current_id]/count, count, d[current_id]]
#                 query_current_id[current_id] = d[current_id]
                
            #print("Output = %s, Current ID: %s, count = %s (values = %s, %s)" % (d[current_id]/count, current_id, d[current_id], target_counts[query_ids[i]], target_counts[query_ids[j]]))

# %%
# display(query_counts)

# %%
# display(overlap_percentages)

# %%
sns.displot(overlap_percentages, binwidth = 0.05)

# %%
# keys = []
# percentages = []
# totals = []
# counts = []
# for key, value in query_matches.items():
#     keys.append(key)
#     percentages.append(value)
#     totals.append(query_counts[key])
#     counts.append(query_current_id[key])

df = pd.DataFrame.from_dict(query_counts, orient='index', columns = ['percentage', 'total', 'count'])

df.index.name = 'id'
df.reset_index(inplace=True)

# df['percentage'] = percentages
# df['total'] = totals
# df['count'] = counts

df
# Out:
#                                             id  percentage  total  count
# 0        GCA_000281215.1_63_GCA_002208745.1_77    0.875000     16     14
# 1        GCA_000281215.1_63_GCA_002208745.1_78    0.428571      7      3
# 2         GCA_000007565.2_1_GCA_000281215.1_63    0.428571      7      3
# 3         GCA_000007565.2_2_GCA_000281215.1_63    0.857143      7      6
# 4        GCA_002208745.1_77_GCA_002208745.1_78    0.857143      7      6
# ...                                        ...         ...    ...    ...
# 45537  GCA_000281215.1_288_GCA_000281215.1_289    1.000000      2      2
# 45538  GCA_000281215.1_289_GCA_000281215.1_301    1.000000      2      2
# 45539  GCA_000006765.1_838_GCA_900243355.1_755    1.000000      4      4
# 45540  GCA_000006765.1_841_GCA_900243355.1_774    1.000000      4      4
# 45541  GCA_002355295.1_554_GCA_002355295.1_556    1.000000      2      2
#
# [45542 rows x 4 columns]

# %%
df.to_csv('/Users/thomasnicholson/phd/RNASeq/srna_seqs/version_1/predicted/overlap_values.csv', index=False)

# %%
def combined_alignments(query, combined_d, ids_checked, query_matches):
    combined_ids = [query]
    ids_checked.append(query)
    max_query = query
    for i in range(0, len(query_ids)):
        ids =[query, query_ids[i]]
        ids.sort()
        current_id = "_".join(ids)
        if current_id in query_matches:
            if query_ids[i] in ids_checked:
                for key, value in combined_d.items():
                    if query_ids[i] in value:
                        max_query = key
            else:
                combined_ids.append(query_ids[i])
                ids_checked.append(query_ids[i])
                
                
    if max_query in combined_d:
        for item in combined_ids:
            if item not in combined_d[max_query]:
                combined_d[max_query].append(item)
    else:
        combined_d[max_query] = combined_ids
    return(combined_d, ids_checked)

# %%
combined_d = {}
ids_checked = []
for query in query_ids:
    if query not in ids_checked:
        combined_d, ids_checked = combined_alignments(query = query, combined_d = combined_d, ids_checked = ids_checked, query_matches = query_matches)

# %%
full_list = []
for key, value in combined_d.items():
    for item in value:
        full_list.append(item)
unique_list = []
for key, value in combined_d.items():
    for item in value:
        if item not in unique_list:
            unique_list.append(item)
        else:
            print(item)

# %%
print(len(combined_d))
print(len(full_list))
print(len(unique_list))
# Out:
# 5270
# 7275
# 7275

# %%
# for key, value in combined_d.items():
#     if len(value) > 1:
#         print(key)
#         outFile = open("/Users/thomasnicholson/phd/RNASeq/srna_seqs/version_1/predicted/combined_alignments_ids/%s_combine_list.txt" % key, 'a')
# #         print(value)
#         for item in value:
#             item = item + ".stk\n"
# #             print(item)
#             outFile.write(item)
#     else:
#         outFile = open("/Users/thomasnicholson/phd/RNASeq/srna_seqs/version_1/predicted/combined_alignments_ids/unique_srna_ids/%s_combine_list.txt" % key, 'a')
#         item = key + ".stk\n"
#         outFile.write(item)

# %%
query = "GCA_002813995.1_383"
combined_ids = [query]
combined_d_tmp = {}
ids_checked_tmp = []
ids_checked_tmp.append(query)
max_query = query
combined_ids = [query]
for i in range(0, len(query_ids)):
    ids =[query, query_ids[i]]
    ids.sort()
    current_id = "_".join(ids)
    if current_id in query_matches:
        print(current_id)
        combined_ids.append(query_ids[i])
        print(combined_ids)
        ids_checked_tmp.append(query_ids[i])
        print(ids_checked_tmp)
#         if target_counts[max_query] < target_counts[query_ids[i]]:
#             max_query = query_ids[i]
    
print(combined_ids, max_query)
if max_query in combined_d_tmp:
    for item in combined_ids:
        if item not in combined_d_tmp[max_query]:
                combined_d_tmp[max_query].append(item)
else:
    combined_d_tmp[max_query] = combined_ids
# Out:
# GCA_000210855.2_531_GCA_002813995.1_383
# ['GCA_002813995.1_383', 'GCA_000210855.2_531']
# ['GCA_002813995.1_383', 'GCA_000210855.2_531']
# ['GCA_002813995.1_383', 'GCA_000210855.2_531'] GCA_002813995.1_383

# %%
query = "GCA_002813995.1_385"
combined_ids = [query]
ids_checked_tmp.append(query)
max_query = query
combined_ids = [query]
for i in range(0, len(query_ids)):
    ids =[query, query_ids[i]]
    ids.sort()
    current_id = "_".join(ids)
    if current_id in query_matches:
        if query_ids[i] in ids_checked_tmp:
#             print(query_ids[i])
            for key, value in combined_d_tmp.items():
                if query_ids[i] in value:
                    max_query = key
        else:
            combined_ids.append(query_ids[i])
            ids_checked_tmp.append(query_ids[i])

if max_query in combined_d_tmp:
    for item in combined_ids:
        if item not in combined_d_tmp[max_query]:
                combined_d_tmp[max_query].append(item)
else:
    combined_d_tmp[max_query] = combined_ids

# %%
combined_d_tmp['GCA_002813995.1_383']
# Out:
# ['GCA_002813995.1_383', 'GCA_000210855.2_531']

# %%
combined_d['GCA_000210855.2_531']
# Out:
# ['GCA_002813995.1_385', 'GCA_000210855.2_531']

# %%
ids_checked_tmp
# Out:
# ['GCA_002813995.1_383', 'GCA_000210855.2_531', 'GCA_002813995.1_385']

# %%
combined_d['GCA_900243355.1_786']
# Out:
# ['GCA_900243355.1_786']

# %%
query_matches["GCA_000006765.1_843_GCA_900243355.1_786"]
# Out:
# 1.0

# %%
ids =["GCA_900243355.1_786", "GCA_000006765.1_843"]
ids.sort()
current_id = "_".join(ids)

# %%
current_id
# Out:
# 'GCA_000006765.1_843_GCA_900243355.1_786'

# %%
count = min([target_counts["GCA_900243355.1_786"], target_counts["GCA_000006765.1_843"]])
count
# Out:
# 4

# %%
d[current_id]
# Out:
# 4

# %%
if current_id in d:
    if d[current_id]/count < 1:
        overlap_percentages.append(d[current_id]/count)
    else:
        overlap_percentages.append(1)
    if d[current_id]/count > 0.35:
        query_matches[current_id] = d[current_id]/count
